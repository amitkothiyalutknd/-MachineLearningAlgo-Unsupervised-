# %%
import numpy as ny
import pandas as ps
data1 = ps.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep = ';')
data1.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data1.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data1['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
qual3 = data1[data1.quality == 3]
qual4 = data1[data1.quality == 4]
qual5 = data1[data1.quality == 5]
qual6 = data1[data1.quality == 6]
qual7 = data1[data1.quality == 7]
qual8 = data1[data1.quality == 8]
qual = {'qual3':qual3, 'qual4':qual4, 'qual5':qual5, 'qual6':qual6, 'qual7':qual7, 'qual8':qual8}

# %%
import cufflinks as cs
import plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
py.offline.init_notebook_mode(connected = True)
import plotly.express as px
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x = qual3['alcohol'], y = qual3['quality'], mode = 'markers', name = 'Quality3', marker = dict(size = 12, color = 'olivedrab', symbol = 'circle')))
fig.add_trace(go.Scatter(x = qual5['alcohol'], y = qual5['quality'], mode = 'markers', name = 'Quality5', marker = dict(size = 12, color = 'mediumspringgreen', symbol = 'square')))
fig.update_layout(title = "Cluster Grouping After K=Mean Algo", xaxis_title = 'Alcohol', yaxis_title = 'pH')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fig = go.Figure()
for i in qual:
    fig = fig.add_trace(go.Scatter(x = qual[i]['alcohol'], y = qual[i]['quality'], name = i, mode = 'markers'))
fig.update_layout(title = "Alcohol's Clustering", xaxis_title = 'Alcohol', yaxis_title = 'pH')
fig.show()

# %%
# data1 = data1.head(150)
x = data1.iloc[:, 0:11]
y = data1.iloc[:, 11:]

# %%
from sklearn.model_selection import train_test_split
# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 1)
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2)
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((1279, 11), (320, 11), (1279, 1), (320, 1))

# %%
from sklearn.neighbors import KNeighborsClassifier
knc1 = KNeighborsClassifier(n_neighbors = 42)
knc1.fit(xtrain, ytrain)
# Out:
# C:\Users\Amit Kothiyal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:207: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# KNeighborsClassifier(n_neighbors=42)

# %%
knc1.score(xtest, ytest)
# Out:
# 0.55

# %%
predict1 = knc1.predict(xtest)
predict1
# Out:
# array([5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5,
#        5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, predict1))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         1
#            5       0.50      0.94      0.65        17
#            6       0.75      0.35      0.48        17
#            7       0.00      0.00      0.00         5
#
#     accuracy                           0.55        40
#    macro avg       0.31      0.32      0.28        40
# weighted avg       0.53      0.55      0.48        40
# C:\Users\Amit Kothiyal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\Amit Kothiyal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning:
#
# ...

# %%
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(ytest, predict1)
cm1
# Out:
# array([[ 0,  1,  0,  0],
#        [ 0, 16,  1,  0],
#        [ 0, 11,  6,  0],
#        [ 0,  4,  1,  0]], dtype=int64)

# %%
fig = px.imshow(cm1, text_auto = True, title = 'HeatMap of Confusion Matrix', labels={'x':'Prediction', 'y':'Truth'})
fig.show()

# %%
data2 = data1.sample(n = 200)
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scaler.fit(data2[['alcohol']])
# data2['alcohol'] = scaler.transform(data2[['alcohol']])
# scaler.fit(data1[['quality']])
# data2['quality'] = scaler.transform(data2[['quality']])
data2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 383             8.3             0.260         0.42             2.0      0.080
# 96              6.8             0.775         0.00             3.0      0.102
# 656            10.7             0.430         0.39             2.2      0.106
# 179             8.8             0.610         0.14             2.4      0.067
# 374            14.0             0.410         0.63             3.8      0.089
# ...             ...               ...          ...             ...        ...
# 300             7.5             0.530         0.06             2.6      0.086
# 650            10.7             0.430         0.39             2.2      0.106
# 1018            8.0             0.180         0.37             0.9      0.049
# 292            10.4             0.550         0.23             2.7      0.091
# 406             9.8             0.440         0.47             2.5      0.063
#
# ...

# %%
fig = go.Figure()
fig = fig.add_trace(go.Scatter(x = data2['alcohol'], y = data2['pH'], name = i, mode = 'markers'))
fig.update_layout(title = "Alcohol's Clustering", xaxis_title = 'Alcohol', yaxis_title = 'Quality')
fig.show()

# %%
from sklearn.cluster import KMeans
sse = []
kmnrng = range(1,11)
for k in kmnrng:
    km = KMeans(n_clusters = k)
    km.fit(data2[['alcohol', 'quality']])
    sse.append(km.inertia_)
sse = ps.DataFrame(sse)
sse.rename(columns = {0:'SSE'}, inplace = True)
kmnrng = ps.DataFrame(kmnrng)
kmnrng.rename(columns = {0:'Kmean'}, inplace = True)
kmnelbw = ps.concat([kmnrng, sse], axis=1)
fig = go.Figure()
fig = fig.add_trace(go.Scatter(x = kmnelbw['Kmean'], y = kmnelbw['SSE'], mode = 'lines+markers', name = 'ElbowLine', line = dict(color = 'cyan'), textposition="top right", marker = dict(size = 12, color = 'green', symbol = 'hexagon2')))
fig.add_annotation(x = 4, y = 89, xref = "x", yref = "y", text = "Elbow Point", showarrow = True, font=dict(family = "Courier New, monospace", size=16, color="#ffffff"),
                align = "center", arrowhead = 1, arrowsize = 1, arrowwidth = 2, arrowcolor = "#636363",  ax=20, ay =-20, bordercolor = "#c7c7c7", borderwidth = 2, borderpad = 4, bgcolor = "#ff7f0e", opacity = 0.8)
fig.update_layout(title = "Elbow Graph To Find Out Kmean", xaxis_title = 'KmeanRange', yaxis_title = 'SSE')
fig.show()

# %%
x = data2.iloc[:, 0:11]
y = data2.iloc[:, 11:]
# from sklearn import preprocessing
# from sklearn import utils
# lab = preprocessing.LabelEncoder()
# y = lab.fit_transform(y)
# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 1)
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2)
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((160, 11), (40, 11), (160, 1), (40, 1))

# %%
from sklearn.neighbors import KNeighborsClassifier
knc2 = KNeighborsClassifier(n_neighbors = 25)
knc2.fit(xtrain, ytrain)
# from sklearn.neighbors import NearestNeighbors
# nn = NearestNeighbors(n_neighbors = 6)
# nn.fit(xtrain, ytrain)
# Out:
# C:\Users\Amit Kothiyal\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:207: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# KNeighborsClassifier(n_neighbors=25)

# %%
knc2.score(xtest, ytest)
# Out:
# 0.5

# %%
ytest
# Out:
#       quality
# 142         6
# 1353        5
# 313         5
# 581         5
# 25          5
# 983         6
# 538         7
# 323         6
# 10          5
# 791         5
# 1425        6
# 1209        7
# 227         5
# 893         5
# 1218        6
# 1429        5
# 1241        5
# 1137        6
# 1142        6
# 1579        5
# 1266        6
# 522         5
# 565         5
# 1247        5
# 1548        5
# 13          5
# 779         5
# 859         6
# 256         5
# 1367        6
# 1080        6
# 43          5
# 1322        5
# 1113        6
# 404         5
# 1138        5
# 1208        7
# 1490        6
# 1570        6
# 190         5

# %%
predict2 = knc2.predict(xtest)
predict2
# Out:
# array([5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 6, 6, 6, 5, 6, 5, 5, 5, 5, 6, 6, 5,
#        6, 6, 6, 5, 5, 6, 5, 5, 5, 6, 5, 5, 6, 5, 6, 5, 6, 5], dtype=int64)

# %%
predict2 = ps.DataFrame(predict2)
result1 = ps.concat([xtest, ytest], axis = 1)
result1.reset_index(inplace = True)
result = ps.concat([result1, predict2], axis = 1)
result.rename(columns = {'index':'SampleRows', 'fixed acidity':'FixAcidity' , 'volatile acidity':'VolatileAcidity', 'citric acid':'CitricAcid', 'residual sugar':'ResidualSugar',
                             'chlorides':'Chlorides', 'free sulfur dioxide':'FreeSulfurDioxide', 'total sulfur dioxide':'TotalSulfurDioxide', 'density':'Denisty',
                             'pH':'PH', 'sulphates':'Sulphates', 'alcohol':'Alcohol', 'quality':'TruthQuality', 0:'PredictedQuality'}, inplace = True)
result
# Out:
#     SampleRows  FixAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0          142         5.2            0.340        0.00            1.8
# 1         1353         7.6            0.645        0.03            1.9
# 2          313         8.6            0.470        0.30            3.0
# 3          581        12.3            0.500        0.49            2.2
# 4           25         6.3            0.390        0.16            1.4
# 5          983         9.1            0.500        0.30            1.9
# 6          538        12.9            0.350        0.49            5.8
# 7          323        10.3            0.590        0.42            2.8
# 8           10         6.7            0.580        0.08            1.8
# 9          791         8.8            0.640        0.17            2.9
# 10        1425         8.3            0.260        0.37            1.4
# 11        1209         6.2            0.390        0.43            2.0
# ...

# %%
# query1 = result[result['TruthQuality'] == result['PredictedQuality']]
report = result[result['TruthQuality'] != result['PredictedQuality']]
report
# Out:
#     SampleRows  FixAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0          142         5.2             0.34        0.00            1.8
# 3          581        12.3             0.50        0.49            2.2
# 4           25         6.3             0.39        0.16            1.4
# 6          538        12.9             0.35        0.49            5.8
# 7          323        10.3             0.59        0.42            2.8
# 11        1209         6.2             0.39        0.43            2.0
# 12         227         9.0             0.82        0.14            2.6
# 17        1137        10.4             0.52        0.45            2.0
# 18        1142         6.9             0.45        0.11            2.4
# 19        1579         6.2             0.56        0.09            1.7
# 22         565        12.7             0.60        0.49            2.8
# 23        1247         7.4             0.55        0.19            1.8
# ...

# %%
fig = go.Figure()
# # Add traces
fig.add_trace(go.Scatter(x = report['SampleRows'], y = report['TruthQuality'], mode = 'markers', name = 'Truth', marker = dict(size = 8, color = 'green', symbol = 'cross')))
fig.add_trace(go.Scatter(x = report['SampleRows'], y = report['PredictedQuality'], mode = 'markers', name = 'Prediction', marker = dict(size = 8, color = 'red', symbol = 'diamond')))
fig.update_layout(title = "Actual Vs Prediction", xaxis_title = 'SampleRows', yaxis_title = 'Quality Prediction')
fig.show()

# %%
TQ3 = report[report.TruthQuality == 3]
TQ4 = report[report.TruthQuality == 4]
TQ5 = report[report.TruthQuality == 5]
TQ6 = report[report.TruthQuality == 6]
TQ7 = report[report.TruthQuality == 7]
TQ8 = report[report.TruthQuality == 4]
TQs = {'TQ3':TQ3, 'TQ4':TQ4, 'TQ5':TQ5, 'TQ6':TQ6, 'TQ7':TQ7, 'TQ8':TQ8}
PQ3 = report[report.PredictedQuality == 3]
PQ4 = report[report.PredictedQuality == 4]
PQ5 = report[report.PredictedQuality == 5]
PQ6 = report[report.PredictedQuality == 6]
PQ7 = report[report.PredictedQuality == 7]
PQ8 = report[report.PredictedQuality == 8]
PQs = {'PQ3':PQ3, 'PQ4':PQ4, 'PQ5':PQ5, 'PQ6':PQ6, 'PQ7':PQ7, 'PQ8':PQ8}
fig = go.Figure()
for i, j in zip(TQs, PQs):
    fig = fig.add_trace(go.Scatter(x = TQs[i]['SampleRows'], y = TQs[i]['TruthQuality'], name = i, mode = 'markers', marker_symbol = 'circle-dot',
                                   marker=dict(size=15, line=dict(color='MediumPurple', width=2))))
    fig = fig.add_trace(go.Scatter(x = PQs[j]['SampleRows'], y = PQs[j]['PredictedQuality'], name = j, mode = 'markers', marker_symbol = 'square-dot',
                                   marker=dict(size=15, line=dict(color='mediumaquamarine', width=2))))
    # fig.add_annotation(x = 3, y = 2, xref = "x", yref = "y", text = "Elbow Point", showarrow = True, font=dict(family = "Courier New, monospace", size=16, color="#ffffff"),
#                 align="center", arrowhead=2, arrowsize=1, arrowwidth=2, arrowcolor="#636363",  ax=20, ay=-30, bordercolor="#c7c7c7", borderwidth=2, borderpad=4, bgcolor="#ff7f0e", opacity=0.8)
fig.update_layout(title = 'False Prediction By K-NeighbourNearest', xaxis_title = 'Alcohol', yaxis_title = 'Quality')
fig.show()
